# %%
# Ch03. Detecting features in Images - 6
# Dropout Regularization

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense

# %%
data = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (test_images, test_labels) = data.load_data()

# %%
training_images = training_images / 255.0
test_images = test_images / 255.0

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
with tf.device('/GPU:0'):
    model.fit(training_images,training_labels,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5719 - accuracy: 0.7928
# Epoch 2/5
#  - ETA: 0s - loss: 0.4390 - accuracy: 0.8404
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4076 - accuracy: 0.8511
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3868 - accuracy: 0.8574
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3712 - accuracy: 0.8629

# %%
model.evaluate(test_images,test_labels)
model.evaluate(training_images,training_labels)

# Without Regularization :
# on test set: 0.87
# on training set : 0.89

# Seems dropout made it worse, but prevented overspecializing
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3717 - accuracy: 0.8631
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3172 - accuracy: 0.8829
# [0.3172049820423126, 0.8828833103179932]
