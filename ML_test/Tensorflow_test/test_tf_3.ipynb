# %%
# Ch02. Introduction to Computer Vision - 1
# Designing the Neural Network

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense

# %%
data = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (test_images, test_labels) = data.load_data()

# %%
training_images = training_images / 255.0
test_images = test_images / 255.0

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
with tf.device('/GPU:0'):
    model.fit(training_images,training_labels,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 8s 3ms/step - loss: 0.4984 - accuracy: 0.8254
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3738 - accuracy: 0.8651
# Epoch 3/5
#  - ETA: 4s - loss: 0.3327 - accuracy: 0.8768
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3139 - accuracy: 0.8854
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2964 - accuracy: 0.8915

# %%
model.evaluate(test_images,test_labels)
model.evaluate(training_images,training_labels)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3406 - accuracy: 0.8783
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2659 - accuracy: 0.9027
# [0.2659010887145996, 0.9026833176612854]
